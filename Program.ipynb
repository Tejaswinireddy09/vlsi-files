# %%
######techparameter and value

import pandas as pd
df=pd.read_csv("techfile_format.txt",header=None, on_bad_lines='skip')
df
df1=pd.DataFrame(columns=['techparam','techparam_values'])
a=df[df[0].str.startswith(' techParams(')].index
a
b=df[df[0].str.startswith(' ) ;techParams')].index
b

df_para=df[a[0]:b[0]]
df_para[0]=df_para[0].str.strip(" ;()").str.split()
df1['techparam']=df_para[0].apply(lambda x:x[0])
df1
df1['techparam_values']=df_para[0].apply(lambda x:x[-1])
df1
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_10260\469413250.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_para[0]=df_para[0].str.strip(" ;()").str.split()
#                            techparam techparam_values
# 131                       techParams       techParams
# 132                        parameter            value
# 133                       ----------            -----
# 134                         maskGrid            0.005
# 135                          cadGrid            0.005
# ..                               ...              ...
# 233  active_overlap_contact_eol_edge             0.04
# 234        ipoly_overlap_contact_eol             0.07
# 235   ipoly_overlap_contact_eol_edge             0.04
# ...

# %%
import pandas as pd
df=pd.read_csv("techfile_format.txt",header=None, on_bad_lines='skip')
# df
df2=pd.DataFrame(columns=["PurposeName",'Abbreviation'])
a=df[df[0].str.startswith(' ;User-Defined Purposes:')].index
# a
b=df[df[0].str.startswith(' ) ;techPurposes')].index
b
df_purpose=df[a[0]:b[0]]
df_purpose[0]=df_purpose[0].str.strip(" ;()").str.split()
df2['PurposeName']=df_para[0].apply(lambda x:x[0])
df2
df2['Abbreviation']=df_para[0].apply(lambda x:x[-1])
df2
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_10260\1460264137.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_purpose[0]=df_purpose[0].str.strip(" ;()").str.split()
#                          PurposeName Abbreviation
# 131                       techParams   techParams
# 132                        parameter        value
# 133                       ----------        -----
# 134                         maskGrid        0.005
# 135                          cadGrid        0.005
# ..                               ...          ...
# 233  active_overlap_contact_eol_edge         0.04
# 234        ipoly_overlap_contact_eol         0.07
# 235   ipoly_overlap_contact_eol_edge         0.04
# 236        LEFDEF_OVERLAP_LAYER_NAME    "OVERLAP"
# ...

# %%
### layer definitions
import pandas as pd
df3=pd.DataFrame(columns=["layername","abbrevations"])
df=pd.read_csv("techfile_format.txt",header=None, on_bad_lines='skip')
df
a=df[df[0].str.startswith( ' ;User-Defined Purposes:')].index
a
b=df[df[0].str.startswith(' ) ;techLayers')].index
b
df_para=df[a[0]:b[0]]
df_para[0]=df_para[0].str.strip(" ;()").str.split()
df3['layername']=df_para[0].apply(lambda x:x[0])
df3
df3['abbrevations']=df_para[0].apply(lambda x:x[-1])
df3
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_10260\2081019755.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_para[0]=df_para[0].str.strip(" ;()").str.split()
#         layername abbrevations
# 258  User-Defined    Purposes:
# 259   periphery_g           40
# 260          HVIO           41
# 261           NBL           42
# 262          HVOX           43
# ..            ...          ...
# 468        UHVT_N       UHVT_N
# 469       SRM_LOP      SRM_LOP
# 470           SNA          SNA
# 471         PWELL        PWELL
# 472         IMSOR        IMSOR
#
# [215 rows x 2 columns]

# %%
######techLayers

import pandas as pd
df4=pd.DataFrame()
df=pd.read_csv("techfile_format.txt",header=None, on_bad_lines='skip')
df
a=df[df[0].str.startswith(' ;( LayerName')].index
a
b=df[df[0].str.startswith(' ) ;techLayerPurposePriorities')].index
b
df_layers=df[a[0]:b[0]]
df_layers[0]=df_layers[0].str.strip(" ;()").str.split()
df4['layername']=df_layers[0].apply(lambda x:x[0])
df4
df4['purpose']=df_layers[0].apply(lambda x:x[-1])
df4
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_10260\2914433404.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_layers[0]=df_layers[0].str.strip(" ;()").str.split()
#         layername       purpose
# 348     LayerName  Abbreviation
# 349     ---------  ------------
# 350  User-Defined       Layers:
# 351           ref           ref
# 352        DNWELL        DNWELL
# ..            ...           ...
# 905           SNA           ntn
# 906           SNA         nwsti
# 907           SNA        tpwell
# 908           SNA        dnwell
# 909           SNA         nwell
#
# [562 rows x 2 columns]

# %%
### tech displays
import pandas as pd
df=pd.read_csv("techfile_format.txt",header=None, on_bad_lines='skip')
df5=pd.DataFrame()
a=df[df[0].str.startswith(' techDisplays(')].index
a
b=df[df[0].str.startswith(' ) ;techDisplays')].index
b
df_para=df[a[0]:b[0]]
# df_para
df_para[0]=df_para[0].str.strip(" ;()").str.split()
df_para[0]
df5['LayerName']=df_para[0].apply(lambda x:x[0])
# df5
df5[' Purpose ']=df_para[0].apply(lambda x:x[1:2:1])
# df5
df5[' Packet']=df_para[0].apply(lambda x:x[2:3:1])
# df5
df5['Visible']=df_para[0].apply(lambda x:x[3:4:1])
# df5
df5['Selectable']=df_para[0].apply(lambda x:x[4:5:1])
df5
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_10260\4104677542.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_para[0]=df_para[0].str.strip(" ;()").str.split()
#          LayerName   Purpose          Packet Visible Selectable
# 911   techDisplays         []             []      []         []
# 912      LayerName  [Purpose]       [Packet]   [Vis]      [Sel]
# 913      ---------  [-------]       [------]   [---]      [---]
# 914            ref  [drawing]  [redhidden_L]     [t]        [t]
# 915         DNWELL  [drawing]          [tan]     [t]        [t]
# ...            ...        ...            ...     ...        ...
# 1341           SNA      [ntn]    [annotate7]     [t]        [t]
# ...

# %%
###techLayerProperties
import pandas as pd
df=pd.read_csv("techfile_format.txt",header=None, on_bad_lines='skip')
df6=pd.DataFrame()
a=df[df[0].str.startswith(' ;( PropName ')].index
a
b=df[df[0].str.startswith(' ) ;techLayerProperties')].index
b
df_para=df[a[0]:b[0]]
df_para[0]=df_para[0].str.strip(" ;()").str.split()
df6['purpose']=df_para[0].apply(lambda x:x[0])
df6['purposevalue']=df_para[0].apply(lambda x:x[-1])
df6
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_10260\3411252785.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_para[0]=df_para[0].str.strip(" ;()").str.split()
#               purpose  purposevalue
# 1348         PropName     PropValue
# 1349         --------     ---------
# 1350  sheetResistance   1207.000000
# 1351  sheetResistance      7.540000
# 1352  sheetResistance    145.869995
# 1353  sheetResistance  72715.000000
# 1354  sheetResistance      0.087000
# 1355    routingOffset             0
# 1356     routingPitch      0.390000
# 1357  sheetResistance      0.057000
# 1358    routingOffset             0
# 1359     routingPitch      0.480000
# 1360  sheetResistance      0.057000
# 1361    routingOffset             0
# ...

# %%
#####techDerivedLayers
import pandas as pd
df7=pd.DataFrame()
df=pd.read_csv("techfile_format.txt",header=None, on_bad_lines='skip')
df
a=df[df[0].str.startswith(' ;( DerivedLayerName  ')].index
a
b=df[df[0].str.startswith(' ) ;techDerivedLayers')].index
b
df_para=df[a[0]:b[0]]
df_para[0]=df_para[0].str.strip(" ;()").str.split()
df7['derivedlayername']=df_para[0].apply(lambda x:x[0])
# df7
df7['composition']=df_para[0].apply(lambda x:x[-1])
df7
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_10260\2603036143.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_para[0]=df_para[0].str.strip(" ;()").str.split()
#       derivedlayername   composition
# 1371  DerivedLayerName   composition
# 1372  ----------------  ------------
# 1373              gate            OD
# 1374        gate_core1           OD2
# 1375           gate_io           OD2
# ...                ...           ...
# 1467           gate_3v        DNWELL
# 1468          pgate_3v        DNWELL
# 1469          ngate_3v        DNWELL
# 1470          pgate_2v      pgate_3v
# 1471          ngate_2v      ngate_3v
#
# [101 rows x 2 columns]

# %%
#####layer rules
### functions
import pandas as pd
df=pd.read_csv("techfile_format.txt",header=None, on_bad_lines='skip')
df8=pd.DataFrame()
a=df[df[0].str.startswith(' ;( layer ')].index
# a
b=df[df[0].str.startswith(' ) ;functions')].index
# b
df_para=df[a[0]:b[0]]
df_para[0]=df_para[0].str.strip(" ;()").str.split()
df_para
df8['layer']=df_para[0].apply(lambda x:x[0])
# df7
df8['function']=df_para[0].apply(lambda x:x[1])
# df7
df8['mask number']=df_para[0].apply(lambda x:x[2])
df8
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_10260\3247230016.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_para[0]=df_para[0].str.strip(" ;()").str.split()
#        layer  function   mask number
# 1484   layer  function  [maskNumber]
# 1485   -----  --------  ------------
# 1486  PDKREC   "pwell"             0
# 1487   NWELL   "nwell"             1
# 1488    NIMP   "nplus"             2
# 1489    PIMP   "pplus"             3
# 1490      OD    "diff"             4
# 1491   POLYG    "poly"             5
# 1492    CONT     "cut"             6
# 1493  METAL1   "metal"             7
# 1494   VIA12     "cut"             8
# 1495  METAL2   "metal"             9
# 1496   VIA23     "cut"            10
# ...

# %%
#####routing directions
import pandas as pd
df9=pd.DataFrame()
df=pd.read_csv("techfile_format.txt",header=None, on_bad_lines='skip')
df
a=df[df[0].str.startswith(' routingDirections(')].index
a
b=df[df[0].str.startswith(' ) ;routingDirections')].index
b
df_para=df[a[0]:b[0]]
df_para[0]=df_para[0].str.strip(" ;()").str.split()
df9['routinglayer']=df_para[0].apply(lambda x:x[0])
df9
df9['routing direction']=df_para[0].apply(lambda x:x[-1])
df9
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_10260\3284999803.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_para[0]=df_para[0].str.strip(" ;()").str.split()
#            routinglayer  routing direction
# 1507  routingDirections  routingDirections
# 1508              layer          direction
# 1509              -----          ---------
# 1510              POLYG             "none"
# 1511             METAL1       "horizontal"
# 1512             METAL2         "vertical"
# 1513             METAL3       "horizontal"
# 1514             METAL4         "vertical"
# 1515             METAL5       "horizontal"

# %%
#####  custom viadefs
import pandas as pd
df10=pd.DataFrame()
df=pd.read_csv("techfile_format.txt",header=None, on_bad_lines='skip')
df
a=df[df[0].str.startswith('  ( AP_M5c  ')].index
a
b=df[df[0].str.startswith(' ) ;customViaDefs')].index
b
df_para=df[a[0]:b[0]]
df_para[0]=df_para[0].str.strip(" ;()").str.split()
df_para 
df10['viaDefName']=df_para[0].apply(lambda x:x[0])
# df10
df10['libName']=df_para[0].apply(lambda x:x[1])
# df10
df10['Metalname']=df_para[0].apply(lambda x:x[2])
# df10
df10['viewName']=df_para[0].apply(lambda x:x[3])
# df10
df10['layer1']=df_para[0].apply(lambda x:x[4])
# df10
df10['layer2']=df_para[0].apply(lambda x:x[5])
# df10
df10['resistancepercut']=df_para[0].apply(lambda x:x[6])
# df10
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_10260\3912175830.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_para[0]=df_para[0].str.strip(" ;()").str.split()

# %%
#####routing grids
import pandas as pd
df11=pd.DataFrame()
df=pd.read_csv("techfile_format.txt",header=None, on_bad_lines='skip')
df
a=df[df[0].str.startswith('    routingGrids(')].index
# a
b=df[df[0].str.startswith('    ) ;routingGrids')].index
b
df_para=df[a[0]:b[0]]
df_para[0]=df_para[0].str.strip(" ;()").str.split()
df11['direction']=df_para[0].apply(lambda x:x[0])
df11
df11['value']=df_para[0].apply(lambda x:x[-1])
df11
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_10260\1367752136.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_para[0]=df_para[0].str.strip(" ;()").str.split()
#              direction         value
# 1656      routingGrids  routingGrids
# 1657     verticalPitch          0.41
# 1658   horizontalPitch          0.41
# 1659    verticalOffset         0.205
# 1660  horizontalOffset         0.205
# 1661     verticalPitch          0.46
# 1662   horizontalPitch          0.46
# 1663  horizontalOffset          0.23
# 1664    verticalOffset          0.23
# 1665     verticalPitch          0.41
# 1666   horizontalPitch          0.41
# 1667  horizontalOffset         0.205
# 1668    verticalOffset         0.205
# ...

# %%
import pandas as pd
final=pd.concat([df1,df2,df3,df4,df5,df6,df7,df8,df9,df10,df11],axis=0)
# final
# final[ "layername"].dropna()
final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1557 entries, 131 to 1676
# Data columns (total 27 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   techparam          107 non-null    object
#  1   techparam_values   107 non-null    object
#  2   PurposeName        107 non-null    object
#  3   Abbreviation       107 non-null    object
#  4   layername          777 non-null    object
#  5   abbrevations       215 non-null    object
#  6   purpose            583 non-null    object
#  7   LayerName          435 non-null    object
#  8    Purpose           435 non-null    object
#  9    Packet            435 non-null    object
#  10  Visible            435 non-null    object
#  11  Selectable         435 non-null    object
#  12  purposevalue       21 non-null     object
#  13  layer              44 non-null     object
#  14  function           44 non-null     object
#  15  mask number        44 non-null     object
# ...
